# %%
# media final
# 4 notas
# 10 alunos

# poder mudar somente uma nota de um aluno
# usar conceito de listas

# colocar se está reprovado ou aprovado

listaDeAlunos = []

def menuPrincipal():
    print("MENU PRINCIPAL")
    print("1 - Inserir um novo aluno;")
    print("2 - Alterar um aluno ou nota da lista;")
    print("3 - Consultar lista;")
    print("4 - Plotar gráfico de um aluno;")
    print("5 - Finalizar código")
    valorMenu = float(input("Escolha uma das opções: "))


    if(valorMenu == 1):
        print("-" * 50)
        inserirAluno()
    elif(valorMenu == 2):
        print(type(listaDeAlunos[0]))
        print("-" * 50)
        encerrar()
    elif(valorMenu == 3):
        print("-" * 50)
        consultarTabela()
    elif(valorMenu == 4):
        print("-" * 50)
        print(listaDeAlunos)
        #encerrar()
    elif(valorMenu == 5):
        print("-" * 50)
        encerrar()
    else:
        print("Valor digitado errado, insira outro valor")
        print("-" * 50)
        menuPrincipal()



def inserirAluno():
    while True:
        try:
            nome = input("Digite o nome do aluno: ")
            N1 = float(input("Digite a primeira nota: "))
            N2 = float(input("Digite a segunda nota: "))
            N3 = float(input("Digite a terceira nota: "))
            N4 = float(input("Digite a quarta nota: "))
            media = (N1 + N2 + N3 + N4)/4
            aluno = {'Nome': nome, "Nota 1": N1, "Nota 2": N2, "Nota 3": N3, "Nota 4": N4, "Média": media}
            listaDeAlunos.append(aluno)
            print(listaDeAlunos)
            print("Novo aluno inserido!")
            print("-" * 50)
            return listaDeAlunos, menuPrincipal()
        except ValueError:
            print("Valor digitado incorreto: ")
        

def consultarTabela():
    print("1 - Consultar todos da lista;")
    print("2 - Consultar por nome.")
    print("3 - Voltar")
    consulta = float(input("Escolha uma opção: "))

    if(consulta == 1):
        for n in listaDeAlunos:
            print(n)
    elif(consulta == 2):
        '''
        Dúvida
        Como percorrer dicionarios armazenados dentro de uma lista?
        Quero comparar o nome digitado com os nomes armazenados na key['Nome'] 
        do dicionario, e caso sejam iguais, imprimir no terminal.
        Posteriormente vou usar o mesmo esquema para alterar os valores. 
        '''
        nomeConsulta = str(input("Digite o nome do aluno a ser consultado: "))
        for n in listaDeAlunos:
            for i in aluno['Nome']:
                if(nomeConsulta in listaDeAlunos):
                    print(i)
                else:
                    print("Não tem")
    elif(consulta == 3):
        menuPrincipal()
    else:
        print("Valor digitado inválido")
        consultarTabela()

menuPrincipal()

def encerrar():
    print("Código encerrado")
# Out:
# MENU PRINCIPAL
# 1 - Inserir um novo aluno;
# 2 - Alterar um aluno ou nota da lista;
# 3 - Consultar lista;
# 4 - Plotar gráfico de um aluno;
# 5 - Finalizar código
# --------------------------------------------------
# [{'Nome': 'Natan', 'Nota 1': 2.0, 'Nota 2': 2.0, 'Nota 3': 2.0, 'Nota 4': 2.0, 'Média': 2.0}]
# Novo aluno inserido!
# --------------------------------------------------
# MENU PRINCIPAL
# 1 - Inserir um novo aluno;
# 2 - Alterar um aluno ou nota da lista;
# 3 - Consultar lista;
# 4 - Plotar gráfico de um aluno;
# 5 - Finalizar código
# <class 'dict'>
# --------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Python\Criando gráfico de médias\mediaComListas.ipynb Célula: 1 in <cell line: 95>()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=91'>92</a>         print("Valor digitado inválido")
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=92'>93</a>         consultarTabela()
# ---> <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=94'>95</a> menuPrincipal()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=96'>97</a> def encerrar():
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=97'>98</a>     print("Código encerrado")
#
# d:\Python\Criando gráfico de médias\mediaComListas.ipynb Célula: 1 in menuPrincipal()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=21'>22</a> if(valorMenu == 1):
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=22'>23</a>     print("-" * 50)
# ---> <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=23'>24</a>     inserirAluno()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=24'>25</a> elif(valorMenu == 2):
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=25'>26</a>     print(type(listaDeAlunos[0]))
#
# d:\Python\Criando gráfico de médias\mediaComListas.ipynb Célula: 1 in inserirAluno()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=57'>58</a>     print("Novo aluno inserido!")
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=58'>59</a>     print("-" * 50)
# ---> <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=59'>60</a>     return listaDeAlunos, menuPrincipal()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=60'>61</a> except ValueError:
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=61'>62</a>     print("Valor digitado incorreto: ")
#
# d:\Python\Criando gráfico de médias\mediaComListas.ipynb Célula: 1 in menuPrincipal()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=25'>26</a>     print(type(listaDeAlunos[0]))
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=26'>27</a>     print("-" * 50)
# ---> <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=27'>28</a>     encerrar()
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=28'>29</a> elif(valorMenu == 3):
#      <a href='vscode-notebook-cell:/d%3A/Python/Criando%20gr%C3%A1fico%20de%20m%C3%A9dias/mediaComListas.ipynb#ch0000000?line=29'>30</a>     print("-" * 50)
#
# NameError: name 'encerrar' is not defined
