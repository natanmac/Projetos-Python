# %%
nome = input("Insira o nome do aluno: ")

while True:
    try:
        print("Digite as notas do aluno: ", nome)
        M1 = float(input("Nota 1: "))
        M2 = float(input("Nota 2: "))
        M3 = float(input("Nota 3: "))
        M4 = float(input("Nota 4: "))
        break
    except ValueError:
        print("Valor errado, insira novamente.")

media = (M1 + M2 + M3 + M4)/4

import matplotlib.pyplot as plt

plt.plot(["1ºbim", "2ºbim", "3ºbim", "4ºbim"], [M1, M2, M3, M4])

plt.show()
# Out:
# Digite as notas do aluno:  hahaha
